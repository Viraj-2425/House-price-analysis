# %% [markdown]
# # Bengaluru House Price Data Analysis
#
# This notebook performs:
# - Data Loading
# - Data Cleaning
# - Exploratory Data Analysis (EDA)
# - Missing Value Analysis
# - Price Distribution Analysis
# - Location-wise Analysis
# - Correlation Analysis
# - Key Insights

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('bengaluru_house_prices.csv')
df.head()

# %%
# Dataset Information
print("Shape:", df.shape)
df.info()

# %%
# Missing Values
missing = df.isnull().sum()
missing.sort_values(ascending=False)

# %%
# Statistical Summary
df.describe(include='all')

# %%
# Price Distribution
plt.figure(figsize=(8,5))
plt.hist(df['price'], bins=50)
plt.title('Price Distribution')
plt.xlabel('Price (Lakhs)')
plt.ylabel('Count')
plt.show()

# %%
# Top 10 Locations
top_locations = df['location'].value_counts().head(10)

plt.figure(figsize=(10,5))
top_locations.plot(kind='bar')
plt.title('Top 10 Locations')
plt.ylabel('Count')
plt.show()

# %%
# Average Price by Location
avg_price = df.groupby('location')['price'].mean().sort_values(ascending=False).head(10)
avg_price

# %%
# Correlation Analysis
numeric_df = df.select_dtypes(include=np.number)

corr = numeric_df.corr()

plt.figure(figsize=(6,4))
plt.imshow(corr)
plt.colorbar()
plt.xticks(range(len(corr.columns)), corr.columns, rotation=45)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title('Correlation Matrix')
plt.show()

corr

# %% [markdown]
# ## Key Insights
#
# 1. Identify locations with highest average prices.
# 2. Analyze missing values before model building.
# 3. Observe skewness in property prices.
# 4. Understand relationship between bathrooms, balconies and price.
# 5. Use findings for future machine learning models.
